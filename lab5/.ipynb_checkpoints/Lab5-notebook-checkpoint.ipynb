# %% [markdown]
#  # MTH8408 : Méthodes d'optimisation et contrôle optimal
#  ## Laboratoire 5: Optimisation avec contraintes et calcul variationnel
# Tangi Migot et Paul Raynaud

# %%
pwd() # te dis ou tu te situes
using Pkg
Pkg.activate(".") # activate l'endroit où t'es
Pkg.status()
# Out:
#   Activating project at `~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5`
# Status `~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Project.toml`
#   [54578032] ADNLPModels v0.7.0
# ⌅ [56d4f2e9] Gridap v0.15.5
#   [7073ff75] IJulia v1.24.2
#   [ba0b0d4f] Krylov v0.9.5
#   [a4795742] NLPModels v0.20.0
#   [f4238b75] NLPModelsIpopt v0.10.1
# ⌃ [5049e819] OptimizationProblems v0.5.0
#   [80da258d] PDENLPModels v0.3.4
#   [91a5bcdd] Plots v1.40.2
#   [ff4d7338] SolverCore v0.3.7
#   [37e2e46d] LinearAlgebra
#   [56ddb016] Logging
#   [de0858da] Printf
#   [8dfed614] Test
# Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated`

# %%
using Krylov, LinearAlgebra, Logging, NLPModels, NLPModelsIpopt, Printf, SolverCore, Test

# %%
using PDENLPModels, Gridap

# %% [markdown]
# ## Quelques commentaires en Julia
#
# ### Les kwargs: choix optionnels
#
# Dans le projet du dernier labo, une des questions demandait d'ajouter une option pour utiliser la fonction `lsmr` ou `lsqr`. C'est le cas typique d'arguments optionnels:
# - On veut proposer un choix par défaut à l'utilisateur, par exemple `lsqr`;
# - On veut laisser la possibilité à l'utilisateur de changer;
# - On voudrait aussi pouvoir ajouter d'autres par la suite (sans avoir à tout modifier).

# %%
function dsol(A, b, ϵ; solver :: Function = lsqr)
    (d, stats) = solver(A, b, atol = ϵ)
    return d
end
# Out:
# dsol (generic function with 1 method)

# %% [markdown]
# A noter que l'on donne des valeurs par défaut aux arguments qui apparaissent après le `;`.

# %% [markdown]
# ## Exercice 1: Pénalité quadratique pour les ADNLPModels
#
# Dans cet exercice, on va étudier une version simple d'une méthode de pénalité quadratique pour les problèmes d'optimisation avec contraintes d'égalité.
# ```math
# min f(x) s.à c(x) = 0.
# ```
# Dans les labos précédents, on a déjà utilisé un NLPModel particulier, le ADNLPModel:

# %%
using ADNLPModels, LinearAlgebra, Test
fH(x) = (x[2]+x[1].^2-11)^2 + (x[1]+x[2].^2-7)^2
x0H = [10., 20.]
cH(x) = [x[1]-1]
himmelblau = ADNLPModel(fH, x0H, cH, [0.], [0.])
# Out:
# ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: Generic
#    All variables: ████████████████████ 2      All constraints: ████████████████████ 1
#             free: ████████████████████ 2                 free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                fixed: ████████████████████ 1
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   3               linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 1
#                                                          nnzj: (  0.00% sparsity)   2
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0

# %% [markdown]
# Attention: dans toute la suite de l'exercice on suppose que les bornes sur les contraintes `nlp.meta.lcon` et `nlp.meta.ucon` sont 0 pour simplifier.

# %% [markdown]
# ### Question 1: Transformer un ADNLPModel en un problème pénalisé
# Coder la fonction `quad_penalty_adnlp` qui prend en entrée un ADNLPModel, et un paramètre ρ et qui retourne un nouveau ADNLPModel qui correspond au problème sans contrainte:
# $$
# \min_x f(x) + \frac{\rho}{2}\|c(x)\|^2.
# $$
# Remarque: on peut accèder aux fonctions f et c par `NLPModels.obj()` et `NLPModels.cons()`.

# %%
function quad_penalty_adnlp(nlp :: ADNLPModel, ρ :: Real)
    f = x -> NLPModels.obj(nlp,x)
    c = x -> NLPModels.cons(nlp,x)
    f_quad = x -> f(x) + (ρ/2) * norm(c(x))^2
    nlp_quad = ADNLPModel(f_quad, nlp.meta.x0)
   return nlp_quad
end
# Out:
# quad_penalty_adnlp (generic function with 1 method)

# %%
# Faire des tests pour vérifier que ça fonctionne.

# fH(x) = (x[2]+x[1].^2-11).^2+(x[1]+x[2].^2-7).^2
# x0H = [10., 20.]
# himmelblau = ADNLPModel(fH, x0H)

# %%
himmelblau_quad = quad_penalty_adnlp(himmelblau, 1)
@test himmelblau_quad.meta.ncon == 0
@test obj(himmelblau_quad, zeros(2)) == 170.5
# Out:
# Test Passed

# %%
#Ajouter au moins un autre test similaire avec des contraintes.
ftest(x) = (x[1] + x[2])^2 - (x[1]+x[2])
x0t = [0., 0.]
ct(x) = [x[1]^2 + x[1]]
nlp_test = ADNLPModel(ftest, x0t, ct, [0.], [0.])
nlp_test_quad = quad_penalty_adnlp(nlp_test,1)

@test nlp_test_quad.meta.ncon == 0
@test obj(nlp_test_quad, x0t) == obj(nlp_test, x0t)
# Out:
# Test Passed

# %%
# Ajouter un test au cas ou `nlp.meta.lcon` ou `nlp.meta.ucon` ont des composantes differentes de 0.

@test  isempty(himmelblau_quad.meta.lcon)
@test  isempty(himmelblau_quad.meta.ucon)
# Out:
# Test Passed

# %% [markdown]
# ### Question 2: KKT
# Coder une fonction `KKT_eq_constraint(nlp :: AbstractNLPModel, x, λ)` qui vérifie si le point `x` avec multiplicateur de Lagrange `λ` satisfait les conditions KKT d'un problème avec contraintes d'égalités.

# %%
function KKT_eq_constraint(nlp :: AbstractNLPModel, x, λ; ϵ=10^(-10))
   grad_f = grad(nlp,x)
   jac_c = jac(nlp,x)
   test1 = isapprox(grad_f, jac_c'*λ, atol=ϵ)
   test2 = isapprox(cons(nlp,x), zeros(length(λ)), atol=ϵ)
   return test1 && test2
end
# Out:
# KKT_eq_constraint (generic function with 1 method)

# %%
# test
gtest(x) = x[1] + x[2]
x0t = [0., 0.]
ct(x) = [(x[1]^2) + (x[2]^2)-1]
nlp_test = ADNLPModel(gtest, x0t, ct, [0.], [0.])

x_t = [1/sqrt(2),1/sqrt(2)]
λ_t = 1/sqrt(2)

@test KKT_eq_constraint(nlp_test,x_t,λ_t)
# Out:
# Test Passed

# %% [markdown]
# ### Question 3: méthode de pénalité quadratique

# %%
using NLPModelsIpopt

# %%
function quad_penalty(nlp      :: AbstractNLPModel,
                      x        :: AbstractVector; 
                      ϵ        :: AbstractFloat = 1e-3,
                      η        :: AbstractFloat = 1e6, 
                      σ        :: AbstractFloat = 2.0,
                      max_eval :: Int = 1_000, 
                      max_time :: AbstractFloat = 60.,
                      max_iter :: Int = typemax(Int64)
                      )
    ##### Initialiser cx et gx au point x;
    cx = cons(nlp,x)
    gx = grad(nlp,x)
    ######################################################
    normcx = normcx_old = norm(cx)

    ρ = 1.

    iter = 0    

    el_time = 0.0
    tired   = neval_cons(nlp) > max_eval || el_time > max_time
    status  = :unknown

    start_time = time()
    too_small  = false
    normdual   = norm(gx) #exceptionnellement on ne va pas vérifier toute l'optimalité au début.
    optimal    = max(normcx, normdual) ≤ ϵ
    
    nlp_quad   = quad_penalty_adnlp(nlp, ρ)

    @info log_header([:iter, :nf, :primal, :status, :nd, :Δ],
    [Int, Int, Float64, String, Float64, Float64],
    hdr_override=Dict(:nf => "#F", :primal => "‖F(x)‖", :nd => "‖d‖"))

    while !(optimal || tired || too_small)

        #Appeler Ipopt pour résoudre le problème pénalisé en partant du point x0 = x.
        #utiliser l'option print_level = 0 pour enlever les affichages d'ipopt.
        stats = ipopt(nlp; x0 = x, print_level = 0)
        ################################################
      
        if stats.status == :first_order
            ###### Mettre à jour cx avec la solution renvoyé par Ipopt
            x = stats.solution
            cx = cons(nlp,x)
            ##########################################################
            normcx_old = normcx
            normcx = norm(cx)
        end
        
        if normcx_old > 0.95 * normcx
            ρ *= σ
        end

        @info log_row(Any[iter, neval_cons(nlp), normcx, stats.status])
        
        nlp_quad   = quad_penalty_adnlp(nlp, ρ)

        el_time      = time() - start_time
        iter   += 1
        many_evals   = neval_cons(nlp) > max_eval
        iter_limit   = iter > max_iter
        tired        = many_evals || el_time > max_time || iter_limit || ρ ≥ η
        ##### Utiliser la réalisabilité dual renvoyé par Ipopt pour `normdual`
        normdual     = stats.dual_feas
        ###################################################################
        optimal      = max(normcx, normdual) ≤ ϵ
    end

    status = if optimal 
        :first_order
    elseif tired
        if neval_cons(nlp) > max_eval
            :max_eval
        elseif el_time > max_time
            :max_time
        elseif iter > max_iter
            :max_iter
        else
            :unknown
        end
    elseif too_small
        :stalled
    else
        :unknown
    end

    return GenericExecutionStats(nlp, status = status, solution = x,
                                 objective = obj(nlp, x),
                                 primal_feas = normcx,
                                 dual_feas = normdual,
                                 multipliers = stats.multipliers,
                                 iter = iter, 
                                 elapsed_time = el_time,
                                 solver_specific = Dict(:penalty => ρ))
end
# Out:
# quad_penalty (generic function with 1 method)

# %%
#Faire des tests pour vérifier que ça fonctionne.
stats = quad_penalty(himmelblau, x0H)
@test stats.status == :first_order
@test stats.solution ≈ [1.0008083416169895, 2.709969135758311] atol=1e-2
@test norm(cons(himmelblau, stats.solution)) ≈ 0. atol=1e-3
# Out:
# ┌ Info:   iter      #F    ‖F(x)‖           status       ‖d‖         Δ
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:31
# ┌ Info:      0      49   0.0e+00      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# Test Passed

# %% [markdown]
# Vérifier que la solution rendue vérifie les conditions KKT avec la fonction de la question précédente.

# %%
include("test_set.jl")
# Out:
# Test Summary:  | Pass  Total  Time
# Simple problem |    4      4  2.4s
# Test Summary:          | Pass  Total  Time
# Rosenbrock with ∑x = 1 |    3      3  1.5s
# Test Summary: | Pass  Total  Time
# HS6           |    3      3  1.4s
# Test Summary: | Pass  Total  Time
# HS7           |    3      3  1.7s
# Test.DefaultTestSet("HS7", Any[], 3, false, false, true, 1.710961525112233e9, 1.710961526801199e9, false)

# %%
stats_h = quad_penalty(himmelblau,x0H)

x_h = stats_h.solution
λ_h = stats_h.multipliers
@show λ_h

@test KKT_eq_constraint(himmelblau,x_h,λ_h)
# Out:
# ┌ Info:   iter      #F    ‖F(x)‖           status       ‖d‖         Δ
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:31
# ┌ Info:      0      62   0.0e+00      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# λ_h = Float64[]
# Error During Test at /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:7
#   Test threw exception
#   Expression: KKT_eq_constraint(himmelblau, x_h, λ_h)
#   DimensionMismatch:
#   Stacktrace:
#     [1] mul!(C::Vector{Float64}, xA::Adjoint{Float64, SparseArrays.SparseMatrixCSC{Float64, Int64}}, B::Vector{Float64}, α::Bool, β::Bool)
#       @ SparseArrays /Applications/Julia-1.9.app/Contents/Resources/julia/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:59
#     [2] *
#       @ /Applications/Julia-1.9.app/Contents/Resources/julia/share/julia/stdlib/v1.9/SparseArrays/src/linalg.jl:79 [inlined]
#     [3] KKT_eq_constraint(nlp::ADNLPModel{Float64, Vector{Float64}, Vector{Int64}}, x::Vector{Float64}, λ::Vector{Float64}; ϵ::Float64)
#       @ Main ~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:4
#     [4] KKT_eq_constraint(nlp::ADNLPModel{Float64, Vector{Float64}, Vector{Int64}}, x::Vector{Float64}, λ::Vector{Float64})
#       @ Main ~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:1
#     [5] top-level scope
#       @ /Applications/Julia-1.9.app/Contents/Resources/julia/share/julia/stdlib/v1.9/Test/src/Test.jl:478
#     [6] eval
#       @ ./boot.jl:370 [inlined]
#     [7] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base ./loading.jl:1903
#     [8] #invokelatest#2
#       @ ./essentials.jl:819 [inlined]
#     [9] invokelatest
#       @ ./essentials.jl:816 [inlined]
#    [10] (::VSCodeServer.var"#214#215"{VSCodeServer.NotebookRunCellArguments, String})()
#       @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.75.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:19
#    [11] withpath(f::VSCodeServer.var"#214#215"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#       @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.75.2/scripts/packages/VSCodeServer/src/repl.jl:274
#    [12] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, params::VSCodeServer.NotebookRunCellArguments)
#       @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.75.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#    [13] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::Dict{String, Any})
#       @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.75.2/scripts/packages/JSONRPC/src/typed.jl:67
#    [14] serve_notebook(pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; crashreporting_pipename::String)
#       @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.75.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:139
#    [15] top-level scope
#       @ ~/.vscode/extensions/julialang.language-julia-1.75.2/scripts/notebook/notebook.jl:35
#    [16] include(mod::Module, _path::String)
#       @ Base ./Base.jl:457
#    [17] exec_options(opts::Base.JLOptions)
#       @ Base ./client.jl:307
#    [18] _start()
#       @ Base ./client.jl:522
# Test.FallbackTestSetException("There was an error during testing")
#
#
#
# Stacktrace:
#
#  [1] record(ts::Test.FallbackTestSet, t::Union{Test.Error, Test.Fail})
#
#    @ Test /Applications/Julia-1.9.app/Contents/Resources/julia/share/julia/stdlib/v1.9/Test/src/Test.jl:960
#
#  [2] do_test(result::Test.ExecutionResult, orig_expr::Any)
#
#    @ Test /Applications/Julia-1.9.app/Contents/Resources/julia/share/julia/stdlib/v1.9/Test/src/Test.jl:670
#
#  [3] top-level scope
#
#    @ /Applications/Julia-1.9.app/Contents/Resources/julia/share/julia/stdlib/v1.9/Test/src/Test.jl:478

# %%
gtest(x) = x[1] + x[2]
x0t = [0., 0.]
ct(x) = [(x[1]^2) + (x[2]^2)-1]
nlp_test = ADNLPModel(gtest, x0t, ct, [0.], [0.])
@show nlp_test.meta.y0

stats_test = quad_penalty(nlp_test,x0t)
x_test = stats_test.solution
@show x_test
λ_test= -1/sqrt(2)
@show λ_test


@test KKT_eq_constraint(nlp_test,x_test,λ_test)
# Out:
# nlp_test.meta.y0 = [0.0]
# ┌ Info:   iter      #F    ‖F(x)‖           status       ‖d‖         Δ
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:31
# ┌ Info:      0      17   2.2e-16      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# x_test = [-0.7071067811865476, -0.7071067811865476]
# λ_test = -0.7071067811865475
# Test Passed

# %%
#Fichier de tests à demander.

# %% [markdown]
# ## Exercice 2: Calcul Variationnel

# %% [markdown]
# Dans cet exercice, on considère le problème de calcul variationnel suivant:
# $$
# \min \int_0^1 (\dot{x}(t)^2+2x(t)^2)e^t dt, \quad x(0)=0, x(1)=e - e^{-2}
# $$
#
# modélisé avec `PDENLPModels`.

# %%
function cv_model(n :: Int)

  domain = (0,1) # set the domain
  partition = n
  model = CartesianDiscreteModel(domain,partition) # set discretization
    
  labels = get_face_labeling(model)
  add_tag_from_tags!(labels,"diri1",[2])
  add_tag_from_tags!(labels,"diri0",[1]) # boundary conditions

  order=1
  valuetype=Float64
  reffe = ReferenceFE(lagrangian, valuetype, order)
  V0 = TestFESpace(model, reffe; conformity=:H1, dirichlet_tags=["diri0","diri1"])
  U = TrialFESpace(V0,[0., exp(1)-exp(-2)])

  trian = Triangulation(model)
  degree = 2
  dΩ = Measure(trian,degree) # integration machinery

  # Our objective function
  w(x) = exp(x[1])
  function f(y)
    ∫((∇(y)⊙∇(y) + 2 * y * y) * w) * dΩ
  end

  xin = zeros(Gridap.FESpaces.num_free_dofs(U))
  nlp = GridapPDENLPModel(xin, f, trian, U, V0)
  return nlp
end
# Out:
# cv_model (generic function with 1 method)

# %% [markdown]
# ### Question 1: Résoudre
# Résoudre le NLPModel généré par la fonction `cv_model` pour `n = 16` avec `ipopt` et afficher la solution (attention la solution rendue ne contient pas les valeurs aux bords qu'il faut rajouter).

# %%
nlp_var = cv_model(16)
stats = ipopt(nlp_var)
sol = stats.solution
pushfirst!(sol, 0)
push!(sol, exp(1)-exp(-2))
@show sol
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.14, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       44
#
# Total number of variables............................:       15
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.8202747e+02 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.0987074e+01 0.00e+00 3.02e-14  -1.0 2.40e+00    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.6484800135597375e+00    2.0987074475792042e+01
# Dual infeasibility......:   3.0216136547373433e-14    6.5725203057809267e-14
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.0216136547373433e-14    6.5725203057809267e-14
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total seconds in IPOPT                               = 8.900
#
# EXIT: Optimal Solution Found.
# sol = [0.0, 0.18196306770012807, 0.3542814202913607, 0.5188461331646763, 0.6773749095244441, 0.8314356102360283, 0.9824672217813848, 1.131798576544907, 1.2806651035693914, 1.4302238561349263, 1.5815670345204877, 1.7357341976668708, 1.8937233357803989, 2.056500956855748, 2.2250113233500324, 2.400184960541827, 2.5829465452224323]
# 17-element Vector{Float64}:
#  0.0
#  0.18196306770012807
#  0.3542814202913607
#  0.5188461331646763
#  0.6773749095244441
#  0.8314356102360283
#  0.9824672217813848
#  1.131798576544907
#  1.2806651035693914
#  1.4302238561349263
#  1.5815670345204877
#  1.7357341976668708
#  1.8937233357803989
#  2.056500956855748
#  2.2250113233500324
#  2.400184960541827
#  2.5829465452224323

# %% [markdown]
# ### Question 2: Convergence en `n`
# Afficher sur un même graphique la solution obtenue par `ipopt` pour plusieurs valeurs de `n`.

# %%
import Pkg; Pkg.add("Plots")
using Plots
# Out:
#    Resolving package versions...
#    Installed GR_jll ─────── v0.73.3+0
#    Installed Libmount_jll ─ v2.39.3+0
#    Installed Cairo_jll ──── v1.18.0+1
#    Installed libpng_jll ─── v1.6.43+1
#    Installed XZ_jll ─────── v5.6.1+0
#    Installed PlotUtils ──── v1.4.1
#    Installed Libuuid_jll ── v2.39.3+1
#    Installed Glib_jll ───── v2.80.0+0
#    Installed Plots ──────── v1.40.2
#    Installed GR ─────────── v0.73.3
#     Updating `~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Project.toml`
#   [91a5bcdd] + Plots v1.40.2
#     Updating `~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Manifest.toml`
#   [d1d4a3ce] + BitFlags v0.1.8
#   [35d6a980] + ColorSchemes v3.24.0
#   [3da002f7] + ColorTypes v0.11.4
#   [c3611d14] + ColorVectorSpace v0.10.0
#   [5ae59095] + Colors v0.12.10
#   [f0e56b4a] + ConcurrentUtilities v2.4.1
#   [d38c429a] + Contour v0.6.2
#   [460bff9d] + ExceptionUnwrapping v0.1.10
#   [c87230d0] + FFMPEG v0.4.1
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [1fa38f19] + Format v1.3.6
#   [28b8d3ca] + GR v0.73.3
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.4
#   [1019f520] + JLFzf v0.1.7
#   [b964fa9f] + LaTeXStrings v1.3.1
#   [23fbe1c1] + Latexify v0.16.2
#   [e6f89c97] + LoggingExtras v1.0.3
#   [442fdcdd] + Measures v0.3.2
#   [4d8831e6] + OpenSSL v1.4.2
#   [b98c9c47] + Pipe v1.3.0
#   [ccf2f8ad] + PlotThemes v3.1.0
#   [995b91a9] + PlotUtils v1.4.1
#   [91a5bcdd] + Plots v1.40.2
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [6c6a2e73] + Scratch v1.2.1
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.1.0
#   [2913bbd2] + StatsBase v0.34.2
#   [62fd8b95] + TensorCore v0.1.1
#   [5c2747f8] + URIs v1.5.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.19.0
#   [45397f5d] + UnitfulLatexify v1.6.3
#   [41fe7b60] + Unzip v0.2.0
#   [83423d85] + Cairo_jll v1.18.0+1
#   [2702e6a9] + EpollShim_jll v0.0.20230411+0
#   [2e619515] + Expat_jll v2.5.0+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.13.93+0
#   [d7e528f0] + FreeType2_jll v2.13.1+0
#   [559328eb] + FriBidi_jll v1.0.10+0
#   [0656b61e] + GLFW_jll v3.3.9+0
#   [d2c73de3] + GR_jll v0.73.3+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.80.0+0
#   [3b182d85] + Graphite2_jll v1.3.14+0
#   [2e76f6c2] + HarfBuzz_jll v2.8.1+1
#   [aacddb02] + JpegTurbo_jll v3.0.2+0
#   [c1c5ebd0] + LAME_jll v3.100.1+0
#   [88015f11] + LERC_jll v3.0.0+1
#   [1d63c593] + LLVMOpenMP_jll v15.0.7+0
#   [dd4b983a] + LZO_jll v2.10.1+0
# ⌅ [e9f186c6] + Libffi_jll v3.2.2+1
#   [d4300ac3] + Libgcrypt_jll v1.8.7+0
#   [7e76a0d4] + Libglvnd_jll v1.6.0+0
#   [7add5ba3] + Libgpg_error_jll v1.42.0+0
#   [4b2f31a3] + Libmount_jll v2.39.3+0
# ⌅ [89763e89] + Libtiff_jll v4.5.1+1
#   [38a345b3] + Libuuid_jll v2.39.3+1
#   [e7412a2a] + Ogg_jll v1.3.5+1
#   [458c3c95] + OpenSSL_jll v3.0.13+0
#   [91d4177d] + Opus_jll v1.3.2+0
#   [30392449] + Pixman_jll v0.42.2+0
#   [c0090381] + Qt6Base_jll v6.5.3+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.21.0+1
#   [2381bf8a] + Wayland_protocols_jll v1.31.0+0
#   [aed1982a] + XSLT_jll v1.1.34+0
#   [ffd25f8a] + XZ_jll v5.6.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.0.10+1
#   [c834827a] + Xorg_libSM_jll v1.2.3+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.6+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.11+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.0+4
#   [a3789734] + Xorg_libXdmcp_jll v1.1.4+0
#   [1082639a] + Xorg_libXext_jll v1.3.4+4
#   [d091e8ba] + Xorg_libXfixes_jll v5.0.3+4
#   [a51aa0fd] + Xorg_libXi_jll v1.7.10+4
#   [d1454406] + Xorg_libXinerama_jll v1.1.4+4
#   [ec84b674] + Xorg_libXrandr_jll v1.5.2+4
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.10+4
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.1+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.15.0+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.2+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.6+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.39.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.5.0+0
#   [3161d3a3] + Zstd_jll v1.5.5+0
#   [35ca27e7] + eudev_jll v3.2.9+0
#   [214eeab7] + fzf_jll v0.43.0+0
#   [1a1c6b14] + gperf_jll v3.1.1+0
#   [a4ae2306] + libaom_jll v3.4.0+0
#   [0ac62f75] + libass_jll v0.15.1+0
#   [2db6ffa8] + libevdev_jll v1.11.0+0
#   [f638f0a6] + libfdk_aac_jll v2.0.2+0
#   [36db933b] + libinput_jll v1.18.0+0
#   [b53b4c65] + libpng_jll v1.6.43+1
#   [f27f6e37] + libvorbis_jll v1.3.7+1
#   [009596ad] + mtdev_jll v1.1.6+0
#   [1270edf5] + x264_jll v2021.5.5+0
#   [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.4.1+1
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Libmount_jll
#   ✓ Graphite2_jll
#   ✓ Unitful → ConstructionBaseUnitfulExt
#   ✓ EpollShim_jll
#   ✓ Format
#   ✓ LLVMOpenMP_jll
#   ✓ Xorg_libXau_jll
#   ✓ RecipesBase
#   ✓ libpng_jll
#   ✓ libfdk_aac_jll
#   ✓ LAME_jll
#   ✓ LERC_jll
#   ✓ fzf_jll
#   ✓ JpegTurbo_jll
#   ✓ Ogg_jll
#   ✓ XZ_jll
#   ✓ mtdev_jll
#   ✓ gperf_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ x265_jll
#   ✓ x264_jll
#   ✓ libaom_jll
#   ✓ Zstd_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ Opus_jll
#   ✓ Xorg_xtrans_jll
#   ✓ libevdev_jll
#   ✓ Libffi_jll
#   ✓ Wayland_protocols_jll
#   ✓ Libgpg_error_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ FriBidi_jll
#   ✓ Libuuid_jll
#   ✓ FreeType2_jll
#   ✓ Gettext_jll
#   ✓ ColorVectorSpace → SpecialFunctionsExt
#   ✓ Pixman_jll
#   ✓ JLFzf
#   ✓ StatsBase
#   ? PDENLPModels
#   ✓ eudev_jll
#   ✓ libvorbis_jll
#   ✓ HTTP
#   ✓ Latexify
#   ✓ Wayland_jll
#   ✓ Libgcrypt_jll
#   ✓ Libtiff_jll
#   ✓ Fontconfig_jll
#   ✓ Glib_jll
#   ✓ libinput_jll
#   ✓ XSLT_jll
#   ✓ Xorg_libxcb_jll
#   ✓ Latexify → DataFramesExt
#   ✓ Xorg_xcb_util_jll
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ UnitfulLatexify
#   ✓ Xorg_libXfixes_jll
#   ✓ ColorSchemes
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ GLFW_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ Cairo_jll
#   ✓ xkbcommon_jll
#   ✓ HarfBuzz_jll
#   ✓ Vulkan_Loader_jll
#   ✓ libass_jll
#   ✓ Qt6Base_jll
#   ✓ FFMPEG_jll
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ GR
#   ✓ PlotUtils
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ Plots
#   ✓ Plots → FileIOExt
#   ✓ Plots → UnitfulExt
#   ✓ Plots → IJuliaExt
#   91 dependencies successfully precompiled in 199 seconds. 156 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
#   1 dependency failed but may be precompilable after restarting julia
#   2 dependencies had output during precompilation:
# ┌ PDENLPModels
# │  WARNING: Method definition testargs(Gridap.Arrays.PosNegReindex{A, B} where B where A, Integer) in module Arrays at /Users/jules/.julia/packages/Gridap/EZQEK/src/Arrays/PosNegReindex.jl:10 overwritten in module PDENLPModels at /Users/jules/.julia/packages/PDENLPModels/pW0Iv/src/PDENLPModels.jl:16.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ Plots
# │  GKS: dlopen(/Users/jules/.julia/artifacts/929d6892d4c6cbd69aa67a767339981456f74a44/lib/cairoplugin.so, 1): Library not loaded: @rpath/libcairo.2.dylib
# │    Referenced from: /Users/jules/.julia/artifacts/929d6892d4c6cbd69aa67a767339981456f74a44/lib/cairoplugin.so
# │    Reason: Incompatible library version: cairoplugin.so requires version 11603.0.0 or later, but libcairo.2.dylib provides version 2.0.0
# └

# %%
## Quelle plage de valeur de n? 3 valeurs proposées dans le pdf 
nlp_var16 = cv_model(16)
stats16 = ipopt(nlp_var16)
sol16 = stats16.solution
pushfirst!(sol16, 0)
push!(sol16, exp(1)-exp(-2))

nlp_var64 = cv_model(64)
stats64 = ipopt(nlp_var64)
sol64 = stats64.solution
pushfirst!(sol64, 0)
push!(sol64, exp(1)-exp(-2))

nlp_var128 = cv_model(128)
stats128 = ipopt(nlp_var128)
sol128 = stats128.solution
pushfirst!(sol128, 0)
push!(sol128, exp(1)-exp(-2))
# Out:
# This is Ipopt version 3.14.14, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       44
#
# Total number of variables............................:       15
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.8202747e+02 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.0987074e+01 0.00e+00 3.02e-14  -1.0 2.40e+00    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.6484800135597375e+00    2.0987074475792042e+01
# Dual infeasibility......:   3.0216136547373433e-14    6.5725203057809267e-14
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.0216136547373433e-14    6.5725203057809267e-14
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total seconds in IPOPT                               = 0.179
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.14.14, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      188
#
# Total number of variables............................:       63
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.1518283e+03 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.0986033e+01 0.00e+00 4.24e-14  -1.0 2.54e+00    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.3536090441322584e+00    2.0986032544330904e+01
# Dual infeasibility......:   4.2433983006517781e-14    3.7836400679225335e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   4.2433983006517781e-14    3.7836400679225335e-13
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total seconds in IPOPT                               = 0.111
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.14.14, running with linear solver MUMPS 5.6.2.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      380
#
# Total number of variables............................:      127
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.3123716e+03 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.0985980e+01 0.00e+00 4.71e-14  -1.0 2.56e+00    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1721510689040422e+00    2.0985980229388002e+01
# Dual infeasibility......:   4.7127906774760018e-14    8.4376949871511907e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   4.7127906774760018e-14    8.4376949871511907e-13
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total seconds in IPOPT                               = 0.092
#
# EXIT: Optimal Solution Found.
# 129-element Vector{Float64}:
#  0.0
#  0.023346590836642457
#  0.04651433594179011
#  0.06950744423663797
#  0.09233007065295136
#  0.11498631705844285
#  0.13748023316849575
#  0.15981581744445067
#  0.1819970179786693
#  0.20402773336658583
#  ⋮
#  2.4002337181067372
#  2.4226394055447575
#  2.445165316680484
#  2.467813255013142
#  2.4905850248451813
#  2.5134824314954174
#  2.5365072815106497
#  2.5596613828757735
#  2.5829465452224323

# %%
rangs16  = range(0, stop=1, length=length(sol16))
rangs64  = range(0, stop=1, length=length(sol64))
rangs128 = range(0, stop=1, length=length(sol128))

plot(rangs128, sol128, xlabel="t", ylabel="x", label="n = 128")
plot!(rangs64, sol64, label="n = 64")
plot!(rangs16, sol16, label="n = 16")
# Out:
# GKS: dlopen(/Users/jules/.julia/artifacts/929d6892d4c6cbd69aa67a767339981456f74a44/lib/cairoplugin.so, 1): Library not loaded: @rpath/libcairo.2.dylib
#   Referenced from: /Users/jules/.julia/artifacts/929d6892d4c6cbd69aa67a767339981456f74a44/lib/cairoplugin.so
#   Reason: Incompatible library version: cairoplugin.so requires version 11603.0.0 or later, but libcairo.2.dylib provides version 2.0.0

# %% [markdown]
# ### Question 3: Comparer à la solution exacte
#
# La solution exacte est $x(t)=e^t - e^{-2t}$ et la valeur optimale est $e^3 - 2e^{-3}+1$.

# %%
f = t -> exp(t) - exp(-2t)

solexacte = [f(t) for t ∈ rangs128]

plot(rangs128, sol128, xlabel="t", ylabel="x", label="n = 128")
plot!(rangs64, sol64, label="n = 64")
plot!(rangs16, sol16, label="n = 16")
plot!(rangs128, solexacte, label="Solution exacte")

# %% [markdown]
# Les solutions approchées et exactes sont trop proches pour voir les différences entre les deux. Traçons l'écarte entre chacune des solutions approchées et la solution réelle :

# %%
ecart16 = []
for k = 1:length(sol16)
    push!(ecart16,f(rangs16[k])-sol16[k])
end
ecart64 = []
for k = 1:length(sol64)
    push!(ecart64,f(rangs64[k])-sol64[k])
end
ecart128 = []
for k = 1:length(sol128)
    push!(ecart128,f(rangs128[k])-sol128[k])
end

# %%
plot(rangs16, ecart16, xlabel="t", ylabel="Écart à la solution exacte", label="n = 16")
plot!(rangs64, ecart64, xlabel="t", label="n = 64")
plot!(rangs128, ecart128, xlabel="t", label="n = 128")

# %% [markdown]
# On s'attend naturellement à voir diminuer les écarts lorsque n augmente !

# %% [markdown]
# # Projet de laboratoire 5

# %% [markdown]
# ## Exercice 1

# %%
import Pkg; Pkg.add("OptimizationProblems")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed DataFrames ─── v1.3.6
#    Installed PrettyTables ─ v1.3.1
#     Updating `~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Project.toml`
# ⌃ [5049e819] + OptimizationProblems v0.5.0
#     Updating `~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
# ⌃ [a93c6f00] + DataFrames v1.3.6
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [59287772] + Formatting v0.4.3
#   [41ab1584] + InvertedIndices v1.3.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [4076af6c] + JuMP v1.20.0
#   [e1d29d7a] + Missings v1.1.0
# ⌃ [5049e819] + OptimizationProblems v0.5.0
#   [2dfb63ee] + PooledArrays v1.4.3
# ⌅ [08abe8d2] + PrettyTables v1.3.1
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.11.1
#   [b27032c2] ↑ LibCURL v0.6.3 ⇒ v0.6.4
#   [44cfe95a] ↑ Pkg v1.9.2 ⇒ v1.10.0
#   [2f01184e] ~ SparseArrays ⇒ v1.10.0
#   [10745b16] ↑ Statistics v1.9.0 ⇒ v1.10.0
#   [e66e0078] ↑ CompilerSupportLibraries_jll v1.0.5+0 ⇒ v1.1.0+0
#   [deac9b47] ↑ LibCURL_jll v7.84.0+0 ⇒ v8.4.0+0
#   [e37daf67] + LibGit2_jll v1.6.4+0
#   [29816b5a] ↑ LibSSH2_jll v1.10.2+0 ⇒ v1.11.0+1
#   [c8ffd9c3] ↑ MbedTLS_jll v2.28.2+0 ⇒ v2.28.2+1
#   [14a3606d] ↑ MozillaCACerts_jll v2022.10.11 ⇒ v2023.1.10
#   [4536629a] ↑ OpenBLAS_jll v0.3.21+4 ⇒ v0.3.23+4
#   [05823500] ↑ OpenLibm_jll v0.8.1+0 ⇒ v0.8.1+2
#   [bea87d4a] ↑ SuiteSparse_jll v5.10.1+6 ⇒ v7.2.1+1
#   [83775a58] ↑ Zlib_jll v1.2.13+0 ⇒ v1.2.13+1
#   [8e850b90] ↑ libblastrampoline_jll v5.8.0+0 ⇒ v5.8.0+1
#   [8e850ede] ↑ nghttp2_jll v1.48.0+0 ⇒ v1.52.0+1
#   [3f19e933] ↑ p7zip_jll v17.4.0+0 ⇒ v17.4.0+2
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ SoftGlobalScope
#   ✓ AbstractTrees
#   ✓ ConstructionBase
#   ✓ BSON
#   ✓ Combinatorics
#   ✓ Adapt
#   ✓ VersionParsing
#   ✓ SuiteSparse
#   ✓ Libiconv_jll
#   ✓ FillArrays
#   ✓ ZeroMQ_jll
#   ✓ OpenBLAS32_jll
#   ✓ CodecBzip2
#   ✓ Distances
#   ✓ SortingAlgorithms
#   ✓ SolverCore
#   ✓ QuadGK
#   ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#   ✓ Adapt → AdaptStaticArraysExt
#   ✓ FastGaussQuadrature
#   ✓ XML2_jll
#   ✓ Conda
#   ✓ ZMQ
#   ✓ PrettyTables
#   ✓ Distances → DistancesSparseArraysExt
#   ✓ ArrayLayouts
#   ✓ LightXML
#   ✓ Setfield
#   ✓ ArrayInterface
#   ✓ Distances → DistancesChainRulesCoreExt
#   ✓ IJulia
#   ✓ BlockArrays
#   ✓ WriteVTK
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ FiniteDiff
#   ✓ FiniteDiff → FiniteDiffStaticArraysExt
#   ✓ NLSolversBase
#   ✓ LineSearches
#   ✓ NLsolve
#   ✓ JLD2
#   ✓ Gridap
#   ? PDENLPModels
#   ✓ DataFrames
#   ✓ MathOptInterface
#   ✓ Ipopt
#   ✓ NLPModelsIpopt
#   ✓ JuMP
#   ✓ OptimizationProblems
#   47 dependencies successfully precompiled in 300 seconds. 82 already precompiled.
#   1 dependency failed but may be precompilable after restarting julia
#   6 dependencies had output during precompilation:
# ┌ OptimizationProblems
# │  WARNING: method definition for #camshape#74 at /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/PureJuMP/camshape.jl:13 declares type variable T but does not use it.
# │  WARNING: method definition for #linsv#570 at /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/PureJuMP/linsv.jl:3 declares type variable T but does not use it.
# │  WARNING: method definition for #mgh01feas#576 at /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/PureJuMP/mgh01feas.jl:3 declares type variable T but does not use it.
# │  WARNING: method definition for #triangle#739 at /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/PureJuMP/triangle.jl:11 declares type variable T but does not use it.
# └
# ┌ DataFrames
# │  WARNING: method definition for #DataFrame#195 at /Users/jules/.julia/packages/DataFrames/JZ7x5/src/dataframe/dataframe.jl:397 declares type variable T but does not use it.
# │  WARNING: method definition for col_ordering at /Users/jules/.julia/packages/DataFrames/JZ7x5/src/abstractdataframe/sort.jl:145 declares type variable O but does not use it.
# └
# ┌ ArrayLayouts
# │  WARNING: could not import Base._rangestyle into ArrayLayouts
# │  WARNING: could not import LinearAlgebra.Abuf into ArrayLayouts
# │  WARNING: could not import LinearAlgebra.Bbuf into ArrayLayouts
# │  WARNING: could not import LinearAlgebra.Cbuf into ArrayLayouts
# │  WARNING: method definition for unsafe_convert at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/ArrayLayouts.jl:90 declares type variable P but does not use it.
# │  WARNING: method definition for unsafe_convert at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/ArrayLayouts.jl:90 declares type variable N but does not use it.
# │  WARNING: method definition for similar at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/mul.jl:79 declares type variable N but does not use it.
# │  WARNING: method definition for similar at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/muladd.jl:41 declares type variable N but does not use it.
# │  WARNING: method definition for similar at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/lmul.jl:22 declares type variable N but does not use it.
# │  WARNING: method definition for similar at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/lmul.jl:22 declares type variable N but does not use it.
# │  WARNING: method definition for materialize! at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/triangular.jl:186 declares type variable UPLO but does not use it.
# │  WARNING: method definition for materialize! at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/triangular.jl:192 declares type variable UPLO but does not use it.
# │  WARNING: method definition for MemoryLayout at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/factorizations.jl:97 declares type variable T but does not use it.
# │  WARNING: method definition for MemoryLayout at /Users/jules/.julia/packages/ArrayLayouts/9PQtL/src/factorizations.jl:99 declares type variable T but does not use it.
# └
# ┌ Gridap
# │  WARNING: method definition for SparseMatrixCSR at /Users/jules/.julia/packages/Gridap/EZQEK/src/Algebra/SparseMatrixCSR.jl:33 declares type variable Ti but does not use it.
# │  WARNING: method definition for SparseMatrixCSR at /Users/jules/.julia/packages/Gridap/EZQEK/src/Algebra/SparseMatrixCSR.jl:33 declares type variable Tv but does not use it.
# │  WARNING: method definition for push_coo! at /Users/jules/.julia/packages/Gridap/EZQEK/src/Algebra/SparseMatrixCSR.jl:166 declares type variable Bi but does not use it.
# │  WARNING: method definition for SymTensorValue at /Users/jules/.julia/packages/Gridap/EZQEK/src/TensorValues/SymTensorValueTypes.jl:23 declares type variable T but does not use it.
# │  WARNING: method definition for SymFourthOrderTensorValue at /Users/jules/.julia/packages/Gridap/EZQEK/src/TensorValues/SymFourthOrderTensorValueTypes.jl:23 declares type variable T but does not use it.
# │  WARNING: method definition for isless at /Users/jules/.julia/packages/Gridap/EZQEK/src/TensorValues/Operations.jl:32 declares type variable T but does not use it.
# │  WARNING: method definition for isless at /Users/jules/.julia/packages/Gridap/EZQEK/src/TensorValues/Operations.jl:32 declares type variable D but does not use it.
# │  WARNING: method definition for get_polytopes at /Users/jules/.julia/packages/Gridap/EZQEK/src/Geometry/GridTopologyMocks.jl:81 declares type variable d but does not use it.
# └
# ┌ BlockArrays
# │  WARNING: could not import Base._maybetail into BlockArrays
# │  WARNING: method definition for _BlockArray at /Users/jules/.julia/packages/BlockArrays/cOFZs/src/blockarray.jl:74 declares type variable T but does not use it.
# │  WARNING: method definition for _BlockArray at /Users/jules/.julia/packages/BlockArrays/cOFZs/src/blockarray.jl:76 declares type variable T but does not use it.
# │  WARNING: method definition for reshape at /Users/jules/.julia/packages/BlockArrays/cOFZs/src/pseudo_blockarray.jl:300 declares type variable N but does not use it.
# │  WARNING: method definition for to_indices at /Users/jules/.julia/packages/BlockArrays/cOFZs/src/views.jl:26 declares type variable R but does not use it.
# │  WARNING: method definition for materialize! at /Users/jules/.julia/packages/BlockArrays/cOFZs/src/blockbroadcast.jl:146 declares type variable Style but does not use it.
# │  WARNING: method definition for similar at /Users/jules/.julia/packages/BlockArrays/cOFZs/src/blocklinalg.jl:47 declares type variable N but does not use it.
# └
# ┌ PDENLPModels
# │  WARNING: Method definition testargs(Gridap.Arrays.PosNegReindex{A, B} where B where A, Integer) in module Arrays at /Users/jules/.julia/packages/Gridap/EZQEK/src/Arrays/PosNegReindex.jl:10 overwritten in module PDENLPModels at /Users/jules/.julia/packages/PDENLPModels/pW0Iv/src/PDENLPModels.jl:16.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └

# %%
using ADNLPModels, OptimizationProblems, OptimizationProblems.ADNLPProblems

# %% [markdown]
# On crée une fonction qui retourne $true$ si un nlp est contraint, par des contraintes d'égalité seulement, et de taille suffisemment petite (n<5000)

# %%
function test_var_eq(nlp)
    L = nlp.meta.lvar
    U = nlp.meta.uvar
    n = length(L)
    not_too_big = n < 5000
    with_constraints = false
    eq_constraints = true
    for k = 1:length(L)
        if L[k] > -Inf && U[k] < Inf
            with_constraints = true
            if L[k] != U[k]
                eq_constraints = false
            end
        end
    end
    return with_constraints && eq_constraints && not_too_big
end
# Out:
# test_var_eq (generic function with 1 method)

# %%
ad_problems = (eval(Meta.parse(problem))() for problem ∈ OptimizationProblems.meta[!, :name])
pb_sc = filter(nlp -> test_var_eq(nlp), collect(ad_problems))
# Out:
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_efgh.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_efgh.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_efgh.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_efgh.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_ijkl.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_ijkl.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_ijkl.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_ijkl.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_mnop.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_mnop.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_mnop.jl:12
# ┌ Warning: dixmaan: number of variables adjusted to be a multiple of 3
# └ @ OptimizationProblems.ADNLPProblems /Users/jules/.julia/packages/OptimizationProblems/nfPUU/src/ADNLPProblems/dixmaan_mnop.jl:12
# 9-element Vector{ADNLPModel{Float64, Vector{Float64}, Vector{Int64}}}:
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: tetra
#    All variables: ████████████████████ 15     All constraints: ████████████████████ 4
#             free: ████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 3                 free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 4
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ████████████████⋅⋅⋅⋅ 12               fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   120             linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 4
#                                                          nnzj: (  0.00% sparsity)   60
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: tetra_duct20
#    All variables: ████████████████████ 3201   All constraints: ████████████████████ 4104
#             free: ████████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 1146              free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 4104
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: █████████████⋅⋅⋅⋅⋅⋅⋅ 2055             fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   5124801          linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 4104
#                                                          nnzj: (  0.00% sparsity)   13136904
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: tetra_foam5
#    All variables: ████████████████████ 4011   All constraints: ████████████████████ 4847
#             free: █████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 867               free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 4847
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ████████████████⋅⋅⋅⋅ 3144             fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   8046066          linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 4847
#                                                          nnzj: (  0.00% sparsity)   19441317
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: tetra_gear
#    All variables: ████████████████████ 2598   All constraints: ████████████████████ 3116
#             free: ███████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 780               free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 3116
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ██████████████⋅⋅⋅⋅⋅⋅ 1818             fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   3376101          linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 3116
#                                                          nnzj: (  0.00% sparsity)   8095368
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: tetra_hook
#    All variables: ████████████████████ 3570   All constraints: ████████████████████ 4675
#             free: ███████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 1200              free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 4675
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ██████████████⋅⋅⋅⋅⋅⋅ 2370             fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   6374235          linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 4675
#                                                          nnzj: (  0.00% sparsity)   16689750
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: triangle
#    All variables: ████████████████████ 8      All constraints: ████████████████████ 3
#             free: █████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 2                 free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 3
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ███████████████⋅⋅⋅⋅⋅ 6                fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   36              linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 3
#                                                          nnzj: (  0.00% sparsity)   24
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: triangle_deer
#    All variables: ████████████████████ 2244   All constraints: ████████████████████ 1896
#             free: ██████████████⋅⋅⋅⋅⋅⋅ 1520              free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 1896
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ███████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 724              fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   2518890          linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 1896
#                                                          nnzj: (  0.00% sparsity)   4254624
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: triangle_pacman
#    All variables: ████████████████████ 1366   All constraints: ████████████████████ 1182
#             free: ███████████████⋅⋅⋅⋅⋅ 994               free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 1182
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ██████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 372              fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   933661          linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 1182
#                                                          nnzj: (  0.00% sparsity)   1614612
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#
#  ADNLPModel - Model with automatic differentiation backend ADModelBackend{
#   ForwardDiffADGradient,
#   ForwardDiffADHvprod,
#   ForwardDiffADJprod,
#   ForwardDiffADJtprod,
#   ForwardDiffADJacobian,
#   ForwardDiffADHessian,
#   ForwardDiffADGHjvprod,
# }
#   Problem name: triangle_turtle
#    All variables: ████████████████████ 4444   All constraints: ████████████████████ 4025
#             free: █████████████████⋅⋅⋅ 3578              free: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            lower: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                lower: ████████████████████ 4025
#            upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                upper: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              low/upp: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            fixed: ████⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 866              fixed: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#           infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               infeas: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#             nnzh: (  0.00% sparsity)   9876790          linear: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#                                                     nonlinear: ████████████████████ 4025
#                                                          nnzj: (  0.00% sparsity)   17887100
#
#   Counters:
#              obj: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 grad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 cons: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#         cons_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0             cons_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 jcon: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jgrad: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                  jac: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0              jac_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#          jac_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                jprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0            jprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#        jprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jtprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0           jtprod_lin: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#       jtprod_nln: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                 hess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0                hprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0
#            jhess: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0               jhprod: ⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅⋅ 0

# %%
nlp_c = pb_sc[1]
stats = quad_penalty(nlp_c, nlp_c.meta.x0)
# Out:
# ┌ Info:   iter      #F    ‖F(x)‖           status       ‖d‖         Δ
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:31
# ┌ Info:      0      10   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      1      16   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      2      22   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      3      28   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      4      34   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      5      40   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      6      46   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      7      52   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      8      58   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:      9      64   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     10      70   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     11      76   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     12      82   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     13      88   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     14      94   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     15     100   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     16     106   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     17     112   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     18     118   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# ┌ Info:     19     124   7.1e-01      first_order
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Lab5-notebook.ipynb:55
# "Execution stats: unknown"

# %%
Pkg.status()
# Out:
# Status `~/Desktop/MTH8408/Git/MTH8408-Hiv24/lab5/Project.toml`
#   [54578032] ADNLPModels v0.7.0
# ⌅ [56d4f2e9] Gridap v0.15.5
#   [7073ff75] IJulia v1.24.2
#   [ba0b0d4f] Krylov v0.9.5
#   [a4795742] NLPModels v0.20.0
#   [f4238b75] NLPModelsIpopt v0.10.1
# ⌃ [5049e819] OptimizationProblems v0.5.0
#   [80da258d] PDENLPModels v0.3.4
#   [91a5bcdd] Plots v1.40.2
#   [ff4d7338] SolverCore v0.3.7
#   [37e2e46d] LinearAlgebra
#   [56ddb016] Logging
#   [de0858da] Printf
#   [8dfed614] Test
# Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated`

# %% [markdown]
# ## Exercice 2

# %% [markdown]
# J'ai trop lutté sans réussir pour tout reprendre sur un fichier.jl, j'ai constamment des problèmes de package non résolu j'ai abandonné !

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# Cf la fin du lab, l'exercice a été traité dans la foulée du lab
