# %% [markdown]
# # Projet de laboratoire 3

# %%
using LinearAlgebra
using SolverCore, SolverBenchmark
using ADNLPModels, NLPModels
using OptimizationProblems, OptimizationProblems.ADNLPProblems
using JSOSolvers

# %% [markdown]
# Le fichier "functions.jl" contient les 4 fonctions définies dans le notebook du labo :
# - armijo
# - limited_bfgs
# - cg_optim
# - armijo_Newton_cg

# %%
include("functions.jl")
# Out:
# armijo_Newton_cg (generic function with 1 method)

# %% [markdown]
# ## Exercice 1 : Méthode quasi-Newton L-BFGS

# %%
nlp = OptimizationProblems.ADNLPProblems.AMPGO02()
limited_bfgs(nlp)
# Out:
# ┌ Info:   iter      f(x)      ‖∇f‖      ∇fᵀd        bk
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:45
# ┌ Info:      0   8.4e-01   3.9e+00  -1.6e+01   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ┌ Info:      1   2.0e-01   2.4e+00  -1.4e+01   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ┌ Info:      2  -8.4e-01   9.9e-01  -4.2e+00   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ┌ Info:      3  -1.4e+00   2.4e+00  -7.4e+00   1.3e-01
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ┌ Info:      4  -1.6e+00   1.7e+00  -2.8e-01   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ┌ Info:      5  -1.7e+00   2.2e-01  -4.2e-03   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ...

# %% [markdown]
# ## Exercice 2 : Méthode Newton-CG

# %%
armijo_Newton_cg(nlp)
# Out:
# ┌ Info:   iter      f(x)      ‖∇f‖      ∇fᵀd        bk
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:177
# ┌ Info:      0   2.0e-01   3.9e+00  -1.6e+01   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      1  -1.3e-01   2.4e+00  -4.4e+00   3.0e-01
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      2  -3.2e-01   2.0e+00  -4.1e-01   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      3  -3.2e-01   1.6e-01  -2.6e-03   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      4  -3.2e-01   1.1e-03  -1.3e-07   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      5  -3.2e-01   4.8e-08
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:218
# "Execution stats: first-order stationary"

# %% [markdown]
# ## Exercice 3

# %%
########################## CRÉATION DU DICTIONNAIRE DE SOLVEURS ##########################
solvers = solvers = Dict(
  :lbfgs1 => model -> lbfgs(model, mem=1),
  :lbfgs5 => model -> lbfgs(model, mem=5),
  :lbfgs20 => model -> lbfgs(model, mem=20),
)


########################## SÉLECTION DES PROBLÈMES POUR LES TEST ##########################
n = 20
meta = OptimizationProblems.meta
problist = meta[(meta.ncon .== 0) .& .!meta.has_bounds .& (5 .<= meta.nvar .<= 100), :name]
ad_problems = (eval(Meta.parse(problem))(;n) for problem ∈ problist)


######################### PASSAGE DES PROBLÈMES DANS LES SOLVEURS #########################
stats = bmark_solvers(
  solvers, ad_problems,
  skipif=prob -> (!unconstrained(prob) || get_nvar(prob) > 100 || get_nvar(prob) < 5),
)
# Out:
# ┌ Info:            Name    nvar    ncon           status      Time      f(x)      Dual    Primal
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:127
# ┌ Info:            NZF1      26       0         max_time   3.0e+01   2.0e+03   1.1e-02   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ┌ Info:         arglina      20       0      first_order   2.3e-03   1.0e+01   1.1e-15   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ┌ Info:         arglinb      20       0      first_order   7.4e-05   4.8e+00   5.1e-09   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ┌ Info:         arglinc      20       0      first_order   9.0e-05   1.1e+01   2.7e-09   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ...

# %%
########################## MISE EN FORME DU TABLEAU DES RÉSULTATS #########################
cols = [:id, :name, :nvar, :objective, :dual_feas, :neval_obj, :neval_grad, :neval_hess, :iter, :elapsed_time, :status]
header = Dict(
  :nvar => "n",
  :objective => "f(x)",
  :dual_feas => "‖∇f(x)‖",
  :neval_obj => "# f",
  :neval_grad => "# ∇f",
  :neval_hess => "# ∇²f",
  :elapsed_time => "t",
)

for solver ∈ keys(solvers)
  pretty_stats(stats[solver][!, cols], hdr_override=header, tf=tf_markdown)
end
# Out:
# |     id |         name |      n |      f(x) |   ‖∇f(x)‖ |      # f |    # ∇f |  # ∇²f |    iter |         t |      status |
# |--------|--------------|--------|-----------|-----------|----------|---------|--------|---------|-----------|-------------|
# |      1 |         NZF1 |     26 |  2.00e+03 |  1.08e-02 |  9643405 | 9356726 |      0 | 6909782 |  3.00e+01 |    max_time |
# |      2 |      arglina |     20 |  1.00e+01 |  1.05e-15 |        2 |       2 |      0 |       1 |  2.33e-03 | first_order |
# |      3 |      arglinb |     20 |  4.81e+00 |  5.07e-09 |       22 |       4 |      0 |       2 |  7.41e-05 | first_order |
# |      4 |      arglinc |     20 |  1.11e+01 |  2.70e-09 |       23 |       4 |      0 |       2 |  8.99e-05 | first_order |
# |      5 |      argtrig |     20 | -3.83e+02 |  5.17e-08 |       61 |      61 |      0 |      55 |  8.01e-04 | first_order |
# ...

# %%
########################### CRÉATION DES PROFILS DE PERFORMANCE ##########################

first_order(df) = df.status .== :first_order
unbounded(df) = df.status .== :unbounded
solved(df) = first_order(df) .| unbounded(df)

costnames = ["time", "obj + grad + hess"]
costs = [
  df -> .!solved(df) .* Inf .+ df.elapsed_time,
  df -> .!solved(df) .* Inf .+ df.neval_obj .+ df.neval_grad .+ df.neval_hess,
]

using Plots
gr()

profile_solvers(stats, costs, costnames)

# %% [markdown]
# #### Comme on peut le voir dans le tableau ci-dessus, 105 problèmes ont été utilisés, tous sans contraintes avec un nombre de variables compris entre 5 et 100. On constate aussi dans le tableau que le problème "biggs6" n'a pas été résolu : l'exécution des algorithmes ci-dessous nous montre que la fonction n'est pas bornée. Les profils de performance nous indique que l'algorithme le plus performant est celui pour **m=20**.

# %%
nlp2 = OptimizationProblems.ADNLPProblems.biggs6()
limited_bfgs(nlp2)
# Out:
# ┌ Info:   iter      f(x)      ‖∇f‖      ∇fᵀd        bk
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:45
# ┌ Info:      0  -4.2e-01   1.2e+01  -1.5e+02   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ┌ Info:      1  -9.0e+01   4.4e+01  -2.5e+03   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:70
# ┌ Info:      2  -3.2e+22   4.1e+22
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:92
# "Execution stats: objective function may be unbounded from below"

# %% [markdown]
# ## Exercice 4

# %% [markdown]
# La meilleure variante était celle avec **m=20** : aucune autre variante ne résoud plus de problèmes que la variante m=20 et celle-ci possède "la courbe la plus à gauche": que ce soit en temps ou en objectif, cette variante est celle qui résoud la plus grosse part des problèmes tout en étant le plus proche de la performance optimale parmi les solveurs !

# %%
########################## CRÉATION DU DICTIONNAIRE DE SOLVEURS ##########################
solvers = solvers = Dict(
  :armijo_Newton_cg => model -> armijo_Newton_cg(model),
  :lbfgs20 => model -> lbfgs(model, mem=20),
)


########################## SÉLECTION DES PROBLÈMES POUR LES TEST ##########################
n = 20
meta = OptimizationProblems.meta
problist = meta[(meta.ncon .== 0) .& .!meta.has_bounds .& (5 .<= meta.nvar .<= 100), :name]
ad_problems = (eval(Meta.parse(problem))(;n) for problem ∈ problist)


######################### PASSAGE DES PROBLÈMES DANS LES SOLVEURS #########################
stats = bmark_solvers(
  solvers, ad_problems,
  skipif=prob -> (!unconstrained(prob) || get_nvar(prob) > 100 || get_nvar(prob) < 5),
)
# Out:
# ┌ Info:            Name    nvar    ncon           status      Time      f(x)      Dual    Primal
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:127
# ┌ Info:            NZF1      26       0      first_order   3.5e+00   2.0e+03   1.6e-05   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ┌ Info:         arglina      20       0      first_order   1.2e+00   1.0e+01   1.0e-15   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ┌ Info:         arglinb      20       0      first_order   1.2e+00   4.8e+00   2.7e-08   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ┌ Info:         arglinc      20       0      first_order   1.1e+00   1.1e+01   3.1e-08   0.0e+00
# └ @ SolverBenchmark /Users/jules/.julia/packages/SolverBenchmark/YM13z/src/run_solver.jl:175
# ...

# %%
########################## MISE EN FORME DU TABLEAU DES RÉSULTATS #########################
cols = [:id, :name, :nvar, :objective, :dual_feas, :neval_obj, :neval_grad, :neval_hess, :iter, :elapsed_time, :status]
header = Dict(
  :nvar => "n",
  :objective => "f(x)",
  :dual_feas => "‖∇f(x)‖",
  :neval_obj => "# f",
  :neval_grad => "# ∇f",
  :neval_hess => "# ∇²f",
  :elapsed_time => "t",
)

for solver ∈ keys(solvers)
  pretty_stats(stats[solver][!, cols], hdr_override=header, tf=tf_markdown)
end
# Out:
# |     id |         name |      n |       f(x) |   ‖∇f(x)‖ |    # f |   # ∇f |  # ∇²f |   iter |         t |      status |
# |--------|--------------|--------|------------|-----------|--------|--------|--------|--------|-----------|-------------|
# |      1 |         NZF1 |     26 |   2.00e+03 |  1.63e-05 |  23360 |   6602 |      0 |   6601 |  3.47e+00 | first_order |
# |      2 |      arglina |     20 |   1.00e+01 |  1.00e-15 |      2 |      2 |      0 |      1 |  1.16e+00 | first_order |
# |      3 |      arglinb |     20 |   4.81e+00 |  2.65e-08 |      2 |      2 |      0 |      1 |  1.17e+00 | first_order |
# |      4 |      arglinc |     20 |   1.11e+01 |  3.09e-08 |      2 |      2 |      0 |      1 |  1.12e+00 | first_order |
# |      5 |      argtrig |     20 |  -3.83e+02 |  5.00e-08 |     23 |     16 |      0 |     15 |  1.47e+00 | first_order |
# |      6 |      arwhead |     20 |   0.00e+00 |  2.89e-12 |      7 |      7 |      0 |      6 |  1.07e+00 | first_order |
# ...

# %%
########################### CRÉATION DES PROFILS DE PERFORMANCE ##########################

first_order(df) = df.status .== :first_order
unbounded(df) = df.status .== :unbounded
solved(df) = first_order(df) .| unbounded(df)

costnames = ["time", "obj + grad + hess"]
costs = [
  df -> .!solved(df) .* Inf .+ df.elapsed_time,
  df -> .!solved(df) .* Inf .+ df.neval_obj .+ df.neval_grad .+ df.neval_hess,
]

using Plots
gr()

profile_solvers(stats, costs, costnames)

# %% [markdown]
# On utilise de nouveau 105 problèmes comme le montre le tableau ci-dessus. On trouve de nouveau grace au tableau un problème non résolu : watson. Ce problème n'est encore une fois pas borné !

# %%
nlp3 = OptimizationProblems.ADNLPProblems.watson()
armijo_Newton_cg(nlp3)
# Out:
# ┌ Info:   iter      f(x)      ‖∇f‖      ∇fᵀd        bk
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:177
# ┌ Info:      0   1.2e+01   2.2e+02  -4.2e+00   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      1   5.9e+00   7.8e+01  -1.1e+01   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      2  -4.2e+87   4.0e+01  -1.6e+03   1.0e+00
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:201
# ┌ Info:      3  -4.2e+87   1.9e+88
# └ @ Main /Users/jules/Desktop/MTH8408/Git/MTH8408-Hiv24/lab3/functions.jl:218
# "Execution stats: objective function may be unbounded from below"
